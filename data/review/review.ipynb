# %% [markdown]
# # SbD4Nano first survey
#
# RDFy the spreadsheet curated at the beginning of the process for:
# - Graphene-based NMs
# - SiO2
# - S-doped TiO2-SiO2
# - ZnO
# - Ag
# - Fe3O4
# - Al
#
#
# ## Background
# More context needed (authors, timeline, purpose)?
#
# ## What's in this notebook
#
# This notebook:
# 1.  Uses the Google API client library to retrieve the [spreadsheet](https://docs.google.com/spreadsheets/d/1VmZJErRoQi099PWj0m8oeMMvta5cjroxLNA3HrcLXCk) with the curated data
# 2.  Describes and characterizes the curated data set. This step includes the programatic retrieval of the license type for each used publication
# 3.  Guides through the process of RDF-ying using `rdflib`
# 4.  Performs some QC SPARQL queries on the generated graphs
#
# ## Status
# This is a work in progress.

# %% [markdown]
# ## Imports and configuration

# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import os.path
import pickle
import pandas as pd
import yaml
from rdflib import Graph, URIRef, Literal, BNode, Namespace
from rdflib.namespace import DC, RDFS, FOAF, DCTERMS, VOID, RDF, XSD, OWL
import requests
import numpy as np

# %% [markdown]
# Each page in the spreadsheet is retrieved according to the range defined in the `config.yaml` config file.

# %%
with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f.read())
    SCOPES = config['SCOPES']
    SPREADSHEET_ID = config['SPREADSHEET']
    RANGE_GO = config['GO']
    RANGE_SIO = config['SiO2']
    RANGE_SDOPED = config['SdopedTiO2SiO2']
    RANGE_ZNO = config['ZnO']
    RANGE_AG = config['Ag']
    RANGE_FEO = config['Fe3O4']
    RANGE_AL = config['Al']
    EMAIL = config['EMAIL']

# %%
def get_spreadsheet_names_in_worksheet(worksheet_id, credentials_file='token.pickle'):
    """Retrieves and prints the names of all spreadsheets within the specified worksheet using Google Sheets API v4.

    Args:
        worksheet_id (str): The ID of the worksheet you want to examine.
        credentials_file (str, optional): The path to the pickled credentials file. Defaults to 'token.pickle'.

    Returns:
        list: A list of spreadsheet names within the worksheet, or an empty list if no spreadsheets are found.

    Raises:
        HttpError: If an error occurs during API interaction.
    """

    try:
        # Load credentials from the pickle file
        with open(credentials_file, 'rb') as token:
            creds = pickle.load(token)

        # Build the Sheets service
        service = build('sheets', 'v4', credentials=creds)

        # Execute the request to get spreadsheet names
        sheets = service.spreadsheets().get(spreadsheetId=worksheet_id).execute()
        sheets = sheets.get('sheets', [])  # Handle edge case where there are no sheets

        # Extract and print spreadsheet names
        spreadsheet_names = [sheet['properties']['title'] for sheet in sheets]
        print("Spreadsheet names in the worksheet:")
        for name in spreadsheet_names:
            print(f"- {name}")

        return spreadsheet_names

    except HttpError as error:
        print(f"Error retrieving spreadsheet names: {error}")
        return []  # Indicate failure by returning an empty list

worksheet_id = SPREADSHEET_ID
spreadsheet_names = get_spreadsheet_names_in_worksheet(worksheet_id)
# Out:
# Spreadsheet names in the worksheet:
# - silica
# - Copia de silica
# - Graphene based NMs
# - sdoped
# - ZnO
# - Ag
# - Fe3O4
# - Al
# - Cytotoxicity studies of NMs

# %% [markdown]
# ## Retrieve data

# %%
def get_google_sheet(sheet, spreadsheet_id=SPREADSHEET_ID):
    creds = None
    range_name = globals()['RANGE_{}'.format(sheet)]
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server()
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    service = build('sheets', 'v4', credentials=creds)
    gsheet = service.spreadsheets().values().get(spreadsheetId=spreadsheet_id, range=range_name).execute()
    values = gsheet.get('values', [])
    if not values:
        print('No data found.')
    else:
        df = pd.DataFrame(values, columns=values[0]).drop(axis=1,index=0)
        return df

# %%
go = get_google_sheet('GO')
sio = get_google_sheet('SIO')
sdoped = get_google_sheet('SDOPED')
zno = get_google_sheet('ZNO')
ag = get_google_sheet('AG')
feo = get_google_sheet('FEO')
al = get_google_sheet('AL')

# %%
df = pd.concat([go,sio,sdoped,zno,ag,feo,al])
df.fillna(value=np.nan, inplace=True)
df = df.apply(lambda x: x.astype(str))
df.describe()
# Out:
#         DOI                                         Manuscript Nanomaterial  \
# count    99                                                 99           99
# unique    2                                                 87           85
# top     nan  Hussain, S.M., Hess, K.L., Gearhart, J.M., Gei...        SWCNT
# freq     76                                                  4            4
#
#                                      Model-cell Exposure Time  \
# count                                        99            99
# unique                                       81            43
# top     A549 cells- human lung cancer cell line      24 hours
# freq                                          4            25
#
#                              Dose Index                       Results Notes  \
# count                          99    99                            99    99
# unique                         86    60                            78    20
# top     10, 25, 50, and 100 μg/mL   MTT  Dose (↑)= Cell viability (↓)   nan
# freq                            4    19                            14    80
#
#        Quote
# count     99   99
# unique     2    2
# top      nan  nan
# freq      98   81

# %%
df.sample(6)
# Out:
#     DOI                                         Manuscript  \
# 1   nan  Monika Remzova, Radek Zouzelka, Tana Brzicova,...
# 32  nan  Uboldi, C., Giudetti, G., Broggi, F., Gillilan...
# 11  nan  Tedja, R., Marquis, C., Lim, M. and Amal, R., ...
# 2   nan  Hussain, S.M., Hess, K.L., Gearhart, J.M., Gei...
# 4   nan  Alshatwi, A.A., Vaiyapuri Subbarayan, P., Rame...
# 11  nan  Tarantini, A., Lanceleur, R., Mourot, A., Lava...
#
#                                          Nanomaterial  \
# 1                                                TiO2
# 32  Pr-SiNPs (NM-200, 10–25nm) and Py-SiNPs (NM-20...
# 11                                  TiO2 (20 nm, P25)
# 2                                       Ag-15, 100 nm
# 4                                         Al (160 nm)
# 11                              SiNPs (15nm and 50nm)
#
#                                            Model-cell        Exposure Time  \
# 1   WST-1 (cell metabolism) and LDH (cell integrit...                  nan
# 32             Immortalized balb/3T3-Mouse fibroblast             72 hours
# 11   A549 and H1299- Human lung epithelial cell lines             24 hours
# 2                             BRL 3A- rat liver cells             24 hours
# 4   HMSC-human bone marrow mesenchymal stem cells ...             12 hours
# 11                      Caco2- Human colon ephitelial  24, 48 and 72 hours
#
#                                Dose  \
# 1                               nan
# 32                      1–100 µg/ml
# 11                   0.3–1000 μg/mL
# 2                      2.5-50 μg/ml
# 4   25, 50, 100, 200, and 400 µg/mL
# 11                0.03–156.3 µg/cm2
#
#                                                 Index  \
# 1                                                 nan
# 32  Cell Viability: MTT, Colony formation assay, C...
# 11                 Trypan Blue,  Alamar Blue and MTS
# 2                                    MTT, LDH and ROS
# 4                                                 MTT
# 11  XTT assay (cell viability),          ELISA and...
#
#                                               Results  \
# 1                                                 nan
# 32  1. MTT: Reduction with 15 nm NPs              ...
# 11  1.H1299 was more susceptible.                 ...
# 2       Dose (↑)= Cell viability (↓), ROS (↑), LDH(↑)
# 4         Dose (↑)= Cell viability (↓), from 200µg/mL
# 11  1. Dose-dependent reduction with 15 nm NPs  (c...
#
#                              Notes Quote
# 1                              nan   nan
# 32                             nan   nan  nan
# 11                             nan   nan
# 2   100 nm was slightly more toxic   nan  nan
# 4                              nan   nan  nan
# 11                             nan   nan  nan

# %% [markdown]
# ## Inspect and parse spreadsheet
#
# The unique values for each column will be printed to determine a parsing strategy for each column.
#
# ### `Nanomaterial`

# %%
print("-","\n- ".join(list(set(df['Nanomaterial']))))
# Out:
# - TiO2 (25 nm?)
# - TiO2 ( 12 to 140 nm); spherical or elongated ; TiO2–P25, TiO2-Sigma and TiO2-Sigma-R (elongated)
# - Al (160 nm)
# - SiNPs (30 nm)
# - SiNPs, Aerosil® 200-Aerosil® Ox50 (12 and 40 nm) and S-SiNPs (200 nm)
# - Al (8-12 nm )
# - TiO2 (50nm)
# - Multi-walled carbon nanotubes (CNT), with/out Fe
# - GO (2.496 nm)
# - TiO2 (21nm)
# - Ag-20 and 40 nm
# - SWCNT and quartz in serum containing (5%) and serum-free (0%) medium.
# - SiC nanoparticles (17 nm)
# - TiO2 (12 to 140 nm); anatase and rutile
# - M-SiNPs (25 and 100 nm)
# - SiO2 (–methyl)
# - SiNP (30nm)
# - Ag-15, 100 nm
# - Fe3O4 (25 nm)
# - GO and carboxyl graphene (CXYG)
# - SWCNT
# - Carbon Black (CB) and Graphene nanoplate (GP)
# - SiNP (62nm)
# - TiO2; anatase (100 ± 10, 25 ± 5, and 5 ± 1 nm) and rutile (100 ± 10 nm)
# - Ag- 30 and 50 nm
# - TiO2 (20 nm, P25)
# - Al (40–47 nm)
# - GO (untreated)                      -sonicated GO                         -Base washed GO                   -s & bw GO
# - ZnO (50–70 nm)
# - TiO2 (5-6nm)
# - TiO2 nanorod (10nm diameter, 50nm long) ; BTO and ATO
# - AHA-SWNTs-6-Aminohexanoic acid–derivatized single-wall carbon nanotubes
# - MWCNT (MW1, MW2, MW3, MW4, MW4, MW5, MW6)- regarding the shape and diameter
# - MWCNTs- 20 nm
# - SiNPs 20 nm (with or without amine or carboxyl coated)
# - SiO2
# - TiO2 (<40 nm)
# - SiNP (58nm)
# - SiNP (2.1, 16.4, 60.4, and 104 nm)
# - TiO2 (4-8nm)
# - Two Py-SiNPs samples (different sizes) one Pr-SiNPs and two C-SiNPs (different sizes), 20–80 nm
# - SiNPs (15nm and 50nm)
# - Al (50-80 nm)
# - SiNPs 150–(200 nm)
# - few layer graphene, FLG, and graphene oxides: GO1, GO2 and GO3
# - SiNPs (15 nm)
# - GO (pGO-5, probe sonicated 5 min) and GS (Graphene sheet)
# - CNT-rm, CNT-agglomerates, CNT-bundles and CNT-pellet
# - TiO2
# - SiNPs (70 nm—with or without lung surfactant)
# - Fe3O4-(30, 47 nm)
# - Py-SiNPs (Aerosil®) and Pr-SiNPs (10–50 nm)
# - SiO2 (20 & 100 nm)                                  SiO2EN100(R), SiO2EN100(−), SiO2EN20(R), and SiO2EN20(−)
# - Fe2O3 coated with FITC-labeled chitosan
# - SiNP (50nm)
# - SiO2 (practically insoluble)
# - S-SiNPs and M-SiNPs (115 nm (with or without amine modification))
# - Graphene NMs (GNPs–pristine, COOH and NH2) and GOs (SLGO and FLGO) 450 nm
# - TiO2 (10 and 20 nm )
# - SiNPs (12 nm)
# - Al (30, 103 nm)
# - SiNPs (19, 43, 68, and 498 nm)
# - M-SiNPs (198 nm)
# - TiO2 (40) nm
# - MWCNTs
# - SiNPs (20 nm)
# - NT-1, NT-2, NT-3 and SWCNT , carbon black (CB14) and quartz (Q)
# - S-SiNPs and M-SiNPs (25 nm)
# - Py-SiNPs (12nm ) and S-SiNPs (50 nm)
# - M-SiNPs (48 nm (surface functionalized with PET and TMS))
# - TiO2 (40–200 nm)
# - SiNP (10 and 20 nm)
# - SiNP (10 and 100 nm)
# - SiNP (25, 46, 183,182, and 188 nm)
# - MWCNT
# - C-SiNP and M-SiNP (100nm)
# - TiO2 (60nm)
# - SiNPs (9,15, 30, and 55 nm)
# - Fe3O4 (30 nm )
# - SiNP (16 (pure or iron-doped) and 60 nm)
# - Pr-SiNPs (NM-200, 10–25nm) and Py-SiNPs (NM-203, 5–30nm); NRT-808 (15nm), NRT-817 (35nm), NRT-820 (80nm) and NRT-944 (90 nm)
# - TiO2 (5nm)
# - SiNPs (10, 50, 300, and 1000 nm (with and without amine modification))
# - Reduced GO
# - SiO2/Au core–shell  =                               AuN@SiO2 and AuS@SiO2 (amine and thiol functionalised silica)

# %% [markdown]
# ### `Model-cell`

# %%
print("-","\n- ".join(list(set(df['Model-cell']))))
# Out:
# - A549 and BEAS-2A cells
# - Caco2- Human colon ephitelial
# - A549, U-87 MG, HepG2 and HL-60
# - H596, H446, and Calu-1-lung epithelial cell lines
# - Kupffer cells-Rat liver macrophage
# ,BRF- Rat liver cells
# - Primary microglial cells-Rat brain macrophage like cells
# - THP-1
# - Neonatal HEKs
# - EA.hy926-Human endothelial
# - A431-human epidermal cells
# - HBMVECs-human brain microvascular endothelial cells
# - A549 -human alveolar carcinoma epithelial cell line
# - A549-Human type II alveolar epithelial, A431-Human skin epithelial
# - A549 & ISO HAS-1
# - Primary Microglial cells-Rat macrophage like cells
# - HaCaT-human epidermal keratinocytes
# - MSTO-211H-Mesothelioma cell line
# - A549-human lung carcinoma cell line
# - HepG2-human liver epithelial
# - human hepatoma cell line, Hep G2
# - V79- Hamster lung fibroblast,                     A549-Human type II alveolar epithelial
# - U373MG human glioblastoma cell line
# - BEAS-2B-human bronchial epithelial cell
# - A549-Human type II alveolar epithelial, MeT-5A-Human bronchial epithelial
# - NRK-52E
# - *Secondary Culture of Rat Cerebellar Astrocytes                  *Primary Culture of Rat Cerebellar Granule Neurons
# - THP-1-human monocytic leukemia cell line
# - J774 -Murine macrophage cells
# -  NRK-52E-rat kidney proximal cells ,
# - H596, H446, and Calu-1-human lung-tumor cell lines
# - HeLa, A549 and H1299-lung epithelial cell
# - H441- Human distal lung epithelial                              ISO-HAS-1- Human Endothelial
# - Platelets-Mouse
# - RAW 264.7-Mouse macrophage
# - HaCaT
# - C2BBe1-Human colon epithelial
#
# - Human bronchial
# epithelial cells;
# nematode
# Caenorhabditis elegans
# - GES-1-Human gastric epithelial, Caco2-Human colon epithelial
# - SMMC-7721-Human hepatoma cell line
# - PBMCs-Lymphocytes, monocytes and dendritic cells
# - mammalian spermatogonial stem cells (SSCs)
# - LoVo cells-human colon carcinoma
# - HT-29-Human colon epithelial
# - A549 and H1299- Human lung epithelial cell lines
# - Ana-1 and MH-S cells-mouse macrophages and Mouse alveolar macrophage
# - human HaCaT skin keratinocytes,
# - Immortalized balb/3T3-Mouse fibroblast
# - JB6 P-mouse epidermal cells
# - HepG2- Human liver epithelial
# - HaCaT cells-Human liver epithelial
# - L929 cell line-murine fibroblasts and BJ-human cells, skin fibroblasts
# - A549-Human type II alveolar epithelial, RAW 264.7-Mouse macrophage
# - Neuro-2A-mouse neuroblastoma
# - NR8383 rat alveolar macrophage cells (CRL-2192TM)
# - HaCaT-Human keratinocyte
# - A549-Human type II alveolar epithelial
#
# - Human epidermal keratinocytes (HEK)
# - A549, THP-1 (Human monocyte) and Biculture: A549/THP-1, Triculture: A549/THP-1/EA.hy926
# - Human sperm
# - MCF7 breast cancer cells.
# - MPMCs-Murine peritoneal mast cells, RBCs-Human red blood cells, Co-culture: MPMC/3T3-Lung co-cultures
# - RAW264.7 (mouse peritoneal macrophage cell line), H9C2 (rat cardiomyocytes cell line), HEK‐293 (human embrionic kidney cell line) and TM3 (mouse testis leydig cell line)
# - NR8383-The rat alveolar macrophage cell line
# - BRL 3A- rat liver cells
# - A549-Human type II alveolar epithelial
# - NRK-52E- Rat kidney epithelial
# - Human peripheral lymphocytes-Human
# - primary cultured rat hippocampal neurons
# - human bronchial epithelial cell, Beas-2B
# - HMSC-human bone marrow mesenchymal stem cells  (CET)
# - U373, C6-Glial Cells
# - A549 cells- human lung cancer cell line
# - LC-02-Human liver epithelial
# - WST-1 (cell metabolism) and LDH (cell integrity) assays-A549 human lung cells
# - BALB/c3T3- Mouse fibroblast and               J774A.1
# - EA.hy926-Human endothelial, Platelets (activated and non-activated)-Human
# - Human skin fibroblast cells (CRL-2522)
# - V79-Hamster lung fibroblast
# - HUVEC-Human vein endothelial
# - HLE B‐3-human lens epithelial cell line (with or without UVB irradiation)
# - J774A.1-Mouse macrophage

# %% [markdown]
# ### `Exposure Time`

# %%
print("-","\n- ".join(list(set(df['Exposure Time']))))
# Out:
# -
# - 24 and 48 hours
# - 72 hours
# - 4 days
# - 12 hours
# - 24, 48 and 72 h
# - 48 hours
# - 0.5–3 hours (0 minute, 30 minutes, 3 hours)
# - 18 Hours
# - 1.24 hours, 2.4–72 hours, 3.10 days in vivo, 4.72 hours
# - 24h, 48h and 72h
# - 24 hours
# - 30 min
# - 12–48 hours
# - 4 hours
# - 24, 48 and 72 hours
# - 4-48 hours
# - 4-20 h
# - 1, 2, 4, 8, 12, 24, and 48 h
# - 72 hours
# - Cultured for 7 days- 24 hours
# - 24 hours
# - 6-48 hours
# - 24 and 48 hours
# - 4 hours
# - -
# - 24 and 72 hours
# - 24hours
# - 72 Hours
# - 1-4 days
# - ALI (5 and 7 h), Sub-merged (24 h)
# - 6, 12, 24 and 48 hours
# - 24 Hours
# - 12–24 hours
# - nan
# - 24, 48 and 72 hours
# - 24 h
# - 25 hours
# - 3 and 24 h
# - 6, 12 and 24 hours
# - 1, 2, 4, 8, 12, 24 and 48 h
# - 3- 6 hours
# - 6, 24 and 48 hours

# %% [markdown]
# ### `Dose`

# %%
print("-","\n- ".join(list(set(df['Dose']))))
# Out:
# - 1–200 μg/ml
# - 0.0–100 µg/ml
# - 25–100 µg/ml
# - 25–1000 µg/ml
# - 0, 2.5, 5.0, 10.0 μg/mL
# - 2.5-50 μg/ml
# - 10–150 µg/ml
# - 1, 5 and 25 µg/ml
# - 6.25–100 µg/m (with LPS and PGN)
# - 0, 1, 10, 100, and 400 g/mL
# - 10 µg/ml
# - 5 µg/cm2 of plate surface
# - 12.5, 25, 50, 100, 200, 400 and 800 µg/mL
# - nan
# - 10, 50, 100, 250 and 500 μg/ml
# - 10 µg/cm2
# - 0.1, 0.2, and 0.4 mg/ml
# - 12–200 µg/ml
# - 50-200 μg/ml
# - 52 μg/cm2 and 117 μg/cm2 (ALI), 15.6 μg/cm2 (sub-merged)
# - 25, 75, 100, 200, 400 and 500 µg/ml
# - 12.5–100 µg/ml
# - 0.06, 0.12 and 0.24 mg/ml
# - 0.25–100 μg/mL
# - 0.6–600 µg/ml
# - 100 µg/ml
# - 3.125-200 μg/mL
# - 250 and 500 mg/ml
# - SiO2EN100R- 3-30 mg/mL             SiO2EN100(−)-2-20  mg/mL       SiO2EN20R- 0.3-3.0 mg/mL       SiO2EN20(−)- 0.2-2.0 mg/mL
# - 10 and 50 μg/ml
# - 250 g μg/L
# - MW1–4: 1–100 mg/mL        MW5 and 6: 0.5–50 mg/
# mL
# - 0.002-0.2 µg/mL
# - 1-10 µM
# - 0, 1, 10, 25, 50, and 100 µg/mL
# - 200 μg/ml
# - 0.1–10 μg/ml
# - 12.5–100 µg/cm2
# - CB at 1 μg/cm2 and 5 μg/cm2. GP at a concentration range of 1 μg/cm2,  5μg/cm2, and
# 10 μg/cm2 in cell media
# - 0.03–156.3 µg/cm2
# - 0, 5, 15, 30, 40, or 50 μg/mL
# - 50–800 µg/ml
# - 1–25 µg/mL (1, 5, 25 µg/mL)
# - 0–123.52 μg/ml
# - 25, 50, 100, and 200 μg/mL
# - 1 – 200 µg/ml
# - 20–1000 µg/ml at a flow rate of 30 µl/min using a microfluidic device
# - 0.3–1000 μg/mL
# - FLG- 0.005 to 90 μg/mL  GOs-0.005 to 100 μg/mL
# - 5, 10, 50 and 100 μg/ml
# - 0–20 μg/ml
# - 0.01, 0.1, 1 and 10 μg/mL
# - 1 mg/L
# - 50–200 µg/ml
# - 50–100 µg/ml
# - -
# - 1–100 µg/ml
# - 10, 25, 50, and 100 μg/mL
# - 200–1000 µg/ml
# - 2.5, 5, 10, 20, and 40 μg/cm2
# - 10-250  μg/ml
# - 0.06, 0.12, or 0.24mg/ml
# - 25–200 µg/ml
# - 0.05 to 0.00000005 mg/ml
# - 0.00156–0.8 mg/ml
# - 0.002–0.2 μg/ml
# - 0.1–1000 µg/ml
# - 25–500 µg/ml
# - 12.5, 25, 50, 100, 200, 400, or 600 μg/ml
# - 0.008, 0.08, 0.8, 8, 80 μg/ml
# - 25, 100, 200, 300, 400, and 500 μg/mL
# - 0-50μg/mL
# - 25, 50, 100, 200, and 400 µg/mL
# - 80 to 0.008 μg/ml
# - 25, 50, 100, 400, and 800 μg/ml
# - 0.0728–7.28 µg/ml
# - 25 and 50 µg/ml
# - 10–600 µg/ml
# - 1, 2, 4, 8, 16 μg/ml of GO                                                              2, 4, 8, 16, 32 μg/ml of  CXYG
# - 25–200 μg/ml
# - 1.5–150 mg/L of five different GFNs 2.20 mg/L and GOs 50, 3.10, and 50 mg/L in vivo 4.5–50 mg/L mixed in K-media
# - 1, 2, 3, 5, 10, 20 and 40 μg/cm2
# - 50–2000 µg/ml
# - 7.5, 15 and 30 μg
# -  0, 10, 50, 100 and 200 μg/mL
# - 10, 50, 100, 200, 400 µg/mL

# %% [markdown]
# ### `Index` (Assay)

# %%
print("-","\n- ".join(list(set(df['Index']))))
# Out:
# -
# - XTT assay (cell viability),          ELISA and caspase-3-assay (apoptosis)
# - LDH assay
# - MTT and LDH assay
# - Colony formation assays, cell viability and cytotoxicity, morphology
# - 2-(4-iodophenyl)-3-(4-nitrophenyl)-5-(2,4-disulfophenyl)-2H-tetrazolium monosodium salt (WST-1)-based assay
# - WST-1
# - Alamar Blue, Neutral Red, coomissia blue and MTT
# - MTT and WST
# - FACS (cell viability) and GSH (oxidative stress)
# - CCK-8 assay, LDH
# - WST-8, Trypan Blue and MTS
# - WST-8, sulforhodamine B assay, Propidium iodide (PI) uptake
# - PI staining
# - LDH, GSH and membrabe integrity, Cytokine Bead Array, ELISA
# - Trypan Blue,  Alamar Blue and MTS
# - *CellTiter-Glo luminescent cell viability assay            *Fluorometric terminal deoxynucleotidyl transferase-mediated dUTP nick end labeling (TUNEL) System                                                   *DAPI
# - flow cytometry , WST-1 assay, Trypan blue staining.
# - MTT, ROS, comet assay, acridine orange staining
# - Cell viability methods :SRB, Impedancemetry (Xcelligence profile), Flow cytometry
# - WST-1 assay, SRB and LDH
# - WST-1
# - MTT, ROS
# - MTT
# - Alamar Blue
# - Cell Viability: MTT, Colony formation assay, Cell transformation assay
# - neutral red (NR)
# - ROS, SOD, MTT and MAP
# - Tryphan blue exclusion and colony formation assay
# - MTT, Annexin V
# - MTT and ROS
# - MTT assay & Brdu assay               Flow cytometry, DAPI
# - MTS, crystal violet assay, LDH, ELISA and Hoechst staining
# - WST-8
# - Commassie, AB, NR, MTT and WST-1
# - LDH, MTT, ROS
# - MTT and WST-8 assays             Including trypan blue and ROS
# - Trypan Blue, MTT and ROS
# - Tryphan blue, Platelet aggregation assay
# - CCK-8, LDH  and ROS
# - WST-8 assay, PI Staining (Cytotoxicity)
# - MTT, LDH
# - WST-1 assay
# - MTS and LDH
# - EZ4U
# - MTT, LDH assay
# - Viability, VCL, VSL, ROS, and NOS levels of sperm
# - ROS, Alamar Blue Assay
# - MTT assay, ROS
# - CCK-8 assay (WST-8), ROS
# - crystal violet staining
# - MTT, LDH and ROS
# - CCK-8 assay (WST-8), LDH assay, ROS , Apoptosis assay(Annexin V) and Flow cytometry
# - nan
# - MTT, LDH  and ROS
# - MTT, LDH, ROS
# - Trypan Blue, MTT, ROS
# - MTS, LDH assay, Western blot (apoptatic effect), ELISA (Pro-inflammatory response(s)) and Hoechst staining (cell morphology)
# - MTT and LDH
# -  calcein-AM uptake and MTT

# %% [markdown]
# ### `Result` (the observed outcome)

# %%
print("-","\n- ".join(list(set(df['Results']))))
# Out:
# - Time & Dose (↑)= Cell viability (↓)
# - 1. 20nm more cytotoxic than 100nm                                                                2. Treatment with 6 mg/mL of SiO2EN100(R) and SiO2EN100(−) reduced the viability by 68% and 65%, respectively                                                                          3. T0.6 and 0.9 mg/mL of SiO2EN20(R) reduced the viability  by 90% and 98%,                                                                                                                 4. 0.6 and 0.8 mg/mL of SiO2EN20(−) reduced the viability by 23% and 96%,                                                                                                                         5. Both SiO2 activated caspase-3 and induced DNA fragmentation in U373MG cells, suggesting the induction of apoptosis.
# - Dose-dependent reduction in BRL
# - Dose (↑)= Cell viability (↓)
# - Dose (↑)= Cell viability (↓), after 3μg/cm2 is significantly HIGH
# - Size (↓)= cell viability(↓) , LDH (↑)
# - Dose (↑)= Cell viability (↓), from 200µg/mL
# - 1.nanoplatelets pose a novel nanohazard and structuretoxicity relationship in nanoparticle toxicolog.                                                                                                                           2. LDH release increased at all concentratıons of GP but CB shad no significant effect                            3.concentrations of GP lead to a significant
# increase in IL-1β expression, whereas CB treatment had no effect
# - No significant effect
# - 1. Cell viability reduction in monocultures                                                          2.LDH increase in all cultures                                                              3.(ELISA)Increase of IL-8 in monocultures and co-culturess                                                          4. Increase in monocultures and co-cultures (Staining)
# - Dose (↑)= Cell viability (↓)
# - nan
# - Dose&Time (↑)= Cell viability (↓), LDH(↑), ROS (↑)
# - Reduction above 250 µg/ml
# - Reduction with 15 nm NPs
# - 1.Dose (↑)= Cell viability (↓),                                                                                                          2.incubating the cells in DFO increased cell viability
# - 1.No significant effect in cell viability                                                          2. Increase at 1000 µg/ml
# - 1. Dose (↑), size (↓) and time (↑)= cell viability (↓)                                                                     2. Dose (↑) and size (↓) = GSH (↑)
# - No significant effect after 6h and 24 hour.  Significant decrease at 150 and 200 µg/ml.
# - Dose (↑)= Cell viability (↓),LDH(↑)
# - Dose (↑)= LDH(↑)
# - 1. Dose-dependent reduction with 15 nm NPs  (cell viability)                                             2. Increase of IL-8 with 15 nm NPs only at 156.3 µg/cm2                             3.Dose-dependent increase with 15 nm NPs (apoptosis)
# - Dose (↑)= Cell viability (↓,) LDH(↑)
# - Dose (↑)= Cell viability (↓), ROS (↑), LDH(↑)
# - statistically
# significant cytotoxic eect
# - 1. MW1, MW2 > MW3, MW4 > MW6 > MW5 due to the diameter.  Shape also matters
# - Dose (↑) & Size (↓)= Cell viability (↓)
# - 1. ROS↑ GO at 16 μg/ml was max. CXYG above 8 μg/ml increased.                                                                   2. No toxicity observed when the concentration was lower than 4μg/ml                                               3. structural damage of the latter (plasma membrane) so they are toxic at 4μg/ml  concentration
# - Dose (↑)= Cell viability (↓), LDH(↑), ROS (↑)
# - 1.Dose (↑)= Cell viability (↓)                                                                                                                        2.H596 more sensitive
# - 1.Low toxicity in MH-S.     2. 25nm showed highest toxicity.                              3. Dose (↑)= Cell viability (↓), LDH(↑), ROS (↑)
# - 1. H9C2 showed the maximal change                 2. Cell Viability decreased more when exposed to BTO, accordingly ROS increased more in BTO
# - 1.H1299 was more susceptible.                         2. Dose(↑30μg/mL )= H1299 Cell viability (↓)   3. There was a slight decrease in A549 at doses above 30μg/mL
# - 1. Dose-dependent cell viability reduction only in RAW 264.7. Amine modified SiNPs were less toxic                                                                                           2. Cytotoxicity increased with M-SiNPs
# - Dose (↑)= Cell viability (↓) LDH(↑)
# - Dose&Time (↑)= Cell viability (↓)
# - 1.CNT cytotoxicity depended on length and purity , the shortest and the purest CNT of panel being the less toxic.
# - ED50: 6–9 µg/ml and 15–22 µg/ml in J774 and 3T3, ,respectively
# - 1. MTT: Reduction with 15 nm NPs                                                     2. Colony formation and cell transformation assays: No significant effect
# - 1. The Brdu findings revealed significantly more death in AuN@SiO2 (amine) treated and exposed cells            2. There is no cytotoxicity at NPs concentration up to 200 µg/mL                                                                             3.  AuN@SiO2 more toxic according to Brdu assay
# - Significant cytotoxicity at 200 μg/ml
# - 1. Dose&Time (↑)= Cell viability (↓), ROS (↑)                      2. 6h and 24h didn't show significant toxicity
# - 1.Increase of apoptotic proteins                                                                2.Cell viability reduction at 600 µg/ml in monocultures                                           3.LDH Increase at 600 µg/ml in all cultures                                                          4. Cells rounded at 600 µg/ml                                                                 5.Increase of siCAM-1, IL-6 and IL-8 (ELISA)
# - 1.Cell viability reduction at 50 µg/ml  with16 nm NPs                                     2.LDH increase  at 50 µg/ml with 16 nm NPs                                                   3. Dose-dependent increase only with Fe doped NPs
# - Dose-dependent reduction in A549
# - 1.No significant effect on cell proliferation. However, at 100μg/mL slight reduction was observed.                                                                                                                                                    2. Significant PI uptake observed after 48h. FLG starting from the concentration of 30 μg/mL (8% of PI uptake) while GO3 induced a slight but significant PI uptake starting from the concentration of 1 μg/mL (25% PI uptake increase).                                                                          3.Significant cytotoxic effects were observed only after long exposure times (72 hours) to high concentrations
# - 1. Not affect sperm viability
# 2. Not hinder the sperm sorting process
# 3.	Not produce significant ROS
# 4. Sperm motility ↓
# - Size and shape dependent reduction in cell viability. Lower than 100nm and spherical ones induced toxicity
# - 1.MTT was not useful!                                                                                           2. the calcein-AM uptake assay- astrocytes, decrease of 33.4% at a concentration of 10 µg/mL, 46.2% at 50 µg/mL, and 63.3% at 100 µg/mL. In neurons, a significant decrease of 41.4% at 50 µg/mL and 52.2% at 100 µg/mL was detected. SiO2-NPs was more toxic to astrocytes compared to neurons.
# - 1. cell viability decreased by 20% and the number of cells in the subG1 phase increased. The increase in ROS formation was observed in SiO2 nanoparticle treated cells. The expression of SOD protein was not changed
# - 1. Reduction only for C-SiNPs                                                                            2. Increase in caspase-3 activation only for C-SiNPs
# - MTT assay failed. GS more damaging than GO to mammalian cells. Increasing the concentration decreased the cell viability, especially higher than 25 μg/mL
# - 1.Dose (↑)= Cell viability (↓)                                                                                                                   2.Serum free media induced toxicity more                                                                                         3. SWCNT have low acute toxicity
# - 1. Size and concentration dependent decrease in cell viability                                                               2.Size-dependent increase (LDH, ROS, Apoptosis, flow cytometry)
# - 1.Dose (↑)= Cell viability (↓)         2. Coated Fe2O3 showed low toxicity
# - 1. SRB: No reduction                                                                                        2. Impedancemetry : No reduction with 25 nm NPs; higher toxicity at lower doses with 100 nm NPs                                                                         3.Flow Cytometry:  Limited toxicity with 25 nm; higher toxicity at lower doses with 100 nm NPs
# - bw-GO showed the highest to toxicity. s-GO and bw-s-GO, had similar cytotoxicities and a size dependent toxicity was observed as GO was generally less toxic than s-GO and bw-s-GO.
# - 1. Negative impact on cell morphology
# 2. Spermatogonial colony formation ↓,
# ROS ↑
# 3. DNA damage, dose-dependent manner
# 4. Apoptosis
# - high toxic
# - 1. Spermatogonial colonies, viable cells ↓ 2. The formation of intracellular vacuoles 3. Cell death, ROS ↑ 4. Cell membrane and DNA damage 5. Apoptosis
# - Size & Dose (↑)= Cell viability (↓) LDH(↑)
# - Dose (↑)= Cell viability (↓) + ROS (↑)
# - 1. Cell Viability dropped by 59%.                              2. NAC increased the viability to 91%                        3. Similar effects in LDH
# - No significant toxic effect on cell viability
# - Reduction with non-porous NPs
# - Dose (↑)= Cell viability (↓), ROS (↑)
# - Significant oxicity at 8 and 80 μg/ml after 48 hours
# - Dose(↑)= Cell viability (↓), especially 10 μg/mL
# - 1.Dose (↑)= Cell viability (↓)                                                                                                                       2. MTT assay showed all toxic whilst WST assay indicated that only Q and CB14 toxic + high concentrations
# - Dose&Time (↑)= Cell viability (↓), LDH(↑)
# - Dose (↑)= Cell viability (↓) ROS(↑)
# - 1. H596 cells were the most sensitive                                                                                                    2. the toxicity of carbon nanotubes increases
# significantly when carbonyl (CdO), carboxyl (COOH), and/
# or hydroxyl (OH) groups are present on their surface.
# - Dose&Time (↑)= Cell viability (↓), ROS (↑) especially with UVB irridiation
# - 1. 100 µg/ml induced the cell toxicity (lower than 50%), 500 µg/ml decreased to about 20%.                                                                                   2. ROS ↑                                                                                                                      3. LDH ↑ when for high concentrations (200, 400 and 500 µg/ml)
# - Size 50nm showed the highest cytotoxicity  Dose (↑)= Cell viability (↓,) Amine surface modificated- non-cytotoxic
# - Dose (↑) & SizE (↓)= Cell proliferation(↓)
# - 1. GNPs exhibited higher toxicity than GOs in Beas2B cells 2. GOs were found to be more toxic in the worms than GNPs 3. SLGO exhibited profoundly greater dose dependency than FLGO
# - 1.pellet and agglomerates are more toxic than raw material and bundles.                                                                  2. PS80 found very useful, raw material was treated with PS80

# %%
print("-","\n- ".join(list(set(df['Notes']))))
# Out:
# -
# - air–liquid interphase (ALI) , pyrogenic samples Py-SiNP
# - PS80:polyoxyethylene sorbitan monooleate
# - the toxicity of carbon nanotubes increases
# significantly when carbonyl (CdO), carboxyl (COOH), and/
# or hydroxyl (OH) groups are present on their surface.
# - Colloidal-SiNP
# - brookite‐type (BTO) and anatase‐type (ATO) nanorods
# - 100 nm was slightly more toxic
# - NOTE:The ideal test for in vitro cell cytotoxicity must not interfere with the compound to be tested. The indicator dyes used in this study (Commassie, AB, NR, MTT and WST-1) are not appropriate for the quantitative toxicity assessment of carbon nanotubes.
# - 20 nm was slightly more toxic
# - Single wall (NT1), multi wall (NT2-3)
# - deferoxamine (DFO)
# - Colloidal-SiNP and Mesaporous-SiNP
# - In combination with lung surfactant, aSNP–plain revealed an increased cytotoxicity in monocultures of A549, aSNP–NH2 caused a slightly augmented toxic effect, whereas aSNP–COOH did not show any toxic alterations.
# - Oxidative stress techniques: DCFH-DA assay, GSH depletion, LPO assay, RT-PCR
# - N-acetyl-L-cysteine (NAC) treated samples showed insignificant cell mortality.
# - pyrogenic samples
# - BRL-Buffola Rat Liver cells
# - nan
# - mesoporous SiO2 (M-SiO2)
# - MTT leading to false positive overestimation

# %%
for i,row in df.iterrows():
    # See how many materials are described
    material_row = str(row['Nanomaterial'])
    if '(' in material_row:
        if ',' in material_row:
            material_row = material_row.split(") ")
            print(material_row)
    if ',' in material_row:
        material_row =  material_row.split(',')
        for i in range(len(material_row)):
            if 'and' in material_row[i]:
                material_row.append(material_row[i].split(' and '))
            if '&' in material_row[i]:
                material_row.append(material_row[i].split(' & '))                
    if '&' in material_row:
        material_row = material_row.split(' & ')
    elif 'and' in material_row:
        material_row = material_row.split(' and ')
    else:
        material_row = [material_row]
    material_row = [i for i in material_row if type(i)!=list]
    print(material_row, type(material_row))
# Out:
# ['Reduced GO'] <class 'list'>
# ['Graphene NMs (GNPs–pristine, COOH and NH2', 'and GOs (SLGO and FLGO', '450 nm']
# [] <class 'list'>
# ['Reduced GO'] <class 'list'>
# ['GO (2.496 nm)'] <class 'list'>
# ['Carbon Black (CB)', 'Graphene nanoplate (GP)'] <class 'list'>
# ['MWCNT (MW1, MW2, MW3, MW4, MW4, MW5, MW6)- regarding the shape and diameter']
# [] <class 'list'>
# ['GO', 'carboxyl graphene (CXYG)'] <class 'list'>
# ['GO (pGO-5, probe sonicated 5 min', 'and GS (Graphene sheet)']
# [] <class 'list'>
# ['GO (untreated)                      -sonicated GO                         -Base washed GO                   -s', 'bw GO                                   '] <class 'list'>
# [] <class 'list'>
# ['Multi-walled carbon nanotubes (CNT), with/out Fe']
# [] <class 'list'>
# ['SWCNT'] <class 'list'>
# ['MWCNTs'] <class 'list'>
# ['MWCNTs'] <class 'list'>
# ['SWCNT', 'quartz in serum containing (5%)', 'serum-free (0%) medium.'] <class 'list'>
# [] <class 'list'>
# ['SWCNT'] <class 'list'>
# ['NT-1, NT-2, NT-3 and SWCNT , carbon black (CB14', 'and quartz (Q)']
# [] <class 'list'>
# ['MWCNT'] <class 'list'>
# ['SWCNT'] <class 'list'>
# ['AHA-SWNTs-6-Aminohexanoic acid–derivatized single-wall carbon nanotubes'] <class 'list'>
# ['SWCNT'] <class 'list'>
# ['MWCNTs- 20 nm'] <class 'list'>
# ['SiO2 (practically insoluble)'] <class 'list'>
# ['SiO2 (–methyl)'] <class 'list'>
# ['SiO2 (20 & 100 nm', '                                 SiO2EN100(R), SiO2EN100(−), SiO2EN20(R), and SiO2EN20(−)']
# [] <class 'list'>
# ['SiO2/Au core–shell  =                               AuN@SiO2', 'AuS@SiO2 (amine', 'thiol functionalised silica)'] <class 'list'>
# ['SiO2 '] <class 'list'>
# ['SiO2 '] <class 'list'>
# ['SiO2 '] <class 'list'>
# ['SiNPs (9,15, 30, and 55 nm)']
# [] <class 'list'>
# ['SiNPs (30 nm)'] <class 'list'>
# ['SiNPs (70 nm—with or without lung surfactant)'] <class 'list'>
# ['SiNPs (15nm', '50nm)'] <class 'list'>
# ['SiNPs (19, 43, 68, and 498\xa0nm)']
# [] <class 'list'>
# ['C-SiNP', 'M-SiNP (100nm)'] <class 'list'>
# ['SiNP (25, 46, 183,182, and 188\xa0nm)']
# [] <class 'list'>
# ['SiNP (10', '100\xa0nm)'] <class 'list'>
# ['SiNP (50nm)'] <class 'list'>
# ['SiNP (2.1, 16.4, 60.4, and 104\xa0nm)']
# [] <class 'list'>
# ['SiNP (62nm)'] <class 'list'>
# ['SiNP (50nm)'] <class 'list'>
# ['SiNP (50nm)'] <class 'list'>
# ['SiNP (16 (pure or iron-doped)', '60\xa0nm)'] <class 'list'>
# ['SiNP (62nm)'] <class 'list'>
# ['SiNP (58nm)'] <class 'list'>
# ['SiNP (58nm)'] <class 'list'>
# ['S-SiNPs', 'M-SiNPs (25\xa0nm)'] <class 'list'>
# ['S-SiNPs', 'M-SiNPs (115\xa0nm (with or without amine modification))'] <class 'list'>
# ['M-SiNPs (25', '100\xa0nm)'] <class 'list'>
# ['M-SiNPs (198 nm)'] <class 'list'>
# ['M-SiNPs (48\xa0nm (surface functionalized with PET', 'TMS))'] <class 'list'>
# ['Py-SiNPs (12nm )', 'S-SiNPs (50\xa0nm)'] <class 'list'>
# ['SiNPs (15\xa0nm)'] <class 'list'>
# ['Pr-SiNPs (NM-200, 10–25nm', 'and Py-SiNPs (NM-203, 5–30nm); NRT-808 (15nm), NRT-817 (35nm), NRT-820 (80nm', 'and NRT-944 (90\xa0nm)']
# [] <class 'list'>
# ['Two Py-SiNPs samples (different sizes', 'one Pr-SiNPs and two C-SiNPs (different sizes), 20–80\xa0nm']
# [] <class 'list'>
# ['SiNPs, Aerosil® 200-Aerosil® Ox50 (12 and 40\xa0nm', 'and S-SiNPs (200\xa0nm)']
# [] <class 'list'>
# ['SiNPs (12\xa0nm)'] <class 'list'>
# ['Py-SiNPs (Aerosil®)', 'Pr-SiNPs (10–50\xa0nm)'] <class 'list'>
# ['SiNPs 150–(200\xa0nm)'] <class 'list'>
# ['SiNPs 20\xa0nm (with or without amine or carboxyl coated)'] <class 'list'>
# ['SiNPs (10, 50, 300, and 1000\xa0nm (with and without amine modification))']
# [] <class 'list'>
# ['SiNPs (20 nm)'] <class 'list'>
# ['SiNP (10', '20\xa0nm)'] <class 'list'>
# ['SiNP (30nm)'] <class 'list'>
# ['SiNPs (15\xa0nm)'] <class 'list'>
# ['SiC nanoparticles (17\xa0nm)'] <class 'list'>
# ['TiO2'] <class 'list'>
# ['TiO2 (21nm)'] <class 'list'>
# ['TiO2 nanorod (10nm diameter, 50nm long', '; BTO and ATO']
# [] <class 'list'>
# ['TiO2 (50nm)'] <class 'list'>
# ['TiO2 (60nm)'] <class 'list'>
# ['TiO2 (25 nm?)'] <class 'list'>
# ['TiO2 (12 to 140 nm); anatase', 'rutile'] <class 'list'>
# ['TiO2 (5nm)'] <class 'list'>
# ['TiO2 (4-8nm)'] <class 'list'>
# ['TiO2; anatase (100 ± 10, 25 ± 5, and 5 ± 1 nm', 'and rutile (100 ± 10 nm)']
# [] <class 'list'>
# ['TiO2 (20 nm, P25)']
# [] <class 'list'>
# ['TiO2 (10', '20 nm )'] <class 'list'>
# ['TiO2 ( 12 to 140 nm); spherical or elongated ; TiO2–P25, TiO2-Sigma and TiO2-Sigma-R (elongated)']
# [] <class 'list'>
# ['TiO2 (50nm)'] <class 'list'>
# ['TiO2 (5-6nm)'] <class 'list'>
# ['TiO2 (40–200 nm)'] <class 'list'>
# ['TiO2 (40)\xa0nm'] <class 'list'>
# ['TiO2 (<40 nm)'] <class 'list'>
# ['ZnO (50–70 nm)'] <class 'list'>
# ['ZnO (50–70 nm)'] <class 'list'>
# ['Ag- 30', '50 nm '] <class 'list'>
# [] <class 'list'>
# ['Ag-20', '40 nm'] <class 'list'>
# ['Fe3O4-(30, 47\xa0nm)']
# [] <class 'list'>
# ['Fe3O4 (30 nm )'] <class 'list'>
# ['Fe3O4 (25 nm)'] <class 'list'>
# ['Fe2O3 coated with FITC-labeled chitosan'] <class 'list'>
# ['Al (30, 103\xa0nm)']
# [] <class 'list'>
# ['Al (8-12 nm )'] <class 'list'>
# ['Al (50-80 nm)'] <class 'list'>
# ['Al (160\xa0nm)'] <class 'list'>
# ['Al (40–47 nm)'] <class 'list'>

# %% [markdown]
# ## Retrieve licenses
#
# This step retrieves the licenses for the journal articles from unpaywall.

# %%
def check_open_access(doi):
    id = doi.split('.org/')[1]
    api_url = 'https://api.unpaywall.org/v2/{}?email={}'.format(id,EMAIL)
    try:
        response = requests.get(api_url).json()
        if response['is_oa'] == True:
            try:
                license = response['best_oa_location']['license']
            except:
                license = 'NA/closed'
            return True, license
        else:
            return False, 'closed'
    except Exception as e:
        print('Exception for: {}. Could not retrieve {})'.format(api_url, e))
        return 'NA'

for doi in set(assertions['doi']):
    if isinstance(doi, str) and 'https' in doi:
        is_oa = check_open_access(doi)
        if isinstance(is_oa[0], bool):
            assertions.loc[assertions['doi'] == doi, 'is_oa'] = is_oa[0]
            assertions.loc[assertions['doi'] == doi, 'license'] = is_oa[1]
# Out:
# /tmp/ipykernel_331867/2756450508.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   assertions.loc[assertions['doi'] == doi, 'is_oa'] = is_oa[0]
# /tmp/ipykernel_331867/2756450508.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'closed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   assertions.loc[assertions['doi'] == doi, 'license'] = is_oa[1]

# %% [markdown]
# Plotting the different license types, we see a majority of non-open papers:

# %% [markdown]
# ## Define RDF namespaces

# %%
# TODO define sbdbel properly (ontological modelling of stated correlations? stated effects? need to discuss)

# %%
sbd = Namespace('https://www.sbd4nano.eu/rdf/#')
sbdbel = Namespace('https://www.sbd4nano.eu/bel/#')
ECO = Namespace('https://evidenceontology.org/#')
kb = Namespace('https://h2020-sbd4nano.github.io/sbd-data-landscape/')
enm = Namespace('http://purl.enanomapper.org/onto/')
ncit = Namespace('http://purl.obolibrary.org/obo/NCIT')
npo = Namespace('http://purl.bioontology.org/ontology/npo#')
pato = Namespace('http://purl.org/obo/owl/PATO#')
cito = Namespace('http://purl.org/spar/cito/')
gracious = Namespace('https://h2020-sbd4nano.github.io/sbd4nano-gracious-owl/gracious.html#')
aop_event = Namespace('https://identifiers.org/aop.events/')
bio = Namespace('http://purl.jp/bio/4/id/')
sio = Namespace('http://semanticscience.org/resource/')
efo = Namespace('http://www.ebi.ac.uk/efo/')
penm = Namespace('http://purl.placeholder.enanomapper.net/')

# %% [markdown]
# ## RDFy

# %% [markdown]
# ## QC SPARQL Queries
